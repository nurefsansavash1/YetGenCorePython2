# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
phone_book = {'Elif': '05531352085','Buse İrem': '5555669','Mina': '5559012',}

name = input("Kimin telefon numarasının gösterilmesini istersiniz? ")

if name in phone_book:
    print(f"The phone number for {name} is {phone_book[name]}.")
else:
    print(f"Sorry, there is no phone number listed for {name}.");
# Out:
# The phone number for Elif is 05531352085.

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
employees = {"Mustafa Köse": ["Ankara", 32, "Muhasebeci"],"Nurefşan Savaş": ["İstanbul", 28, "Pazarlama Uzmanı"],"Fatih Küçük": ["Bursa", 24, "Mühendis"], "Zeynep Karadeniz": ["İzmir", 35, "İnsan Kaynakları Yöneticisi"],
    "Ahmet Demir": ["Bursa", 29, "Mühendis"]}
name = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: ")

if name in employees:
    info = employees[name]
    print(f"{name}= Memleket: {info[0]} Yaş: {info[1]} Görev: {info[2]}")
else:
    print("Girdiğiniz isimle eşleşen bir çalışan bulunamadı.")
# Out:
# Ali Aydın= Memleket: Ankara Yaş: 32 Görev: Muhasebeci

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
öğrencinot = {'Nurefşan': [65 , 96, 70],'Fatma': [67,78, 77],'Ayşe': [72, 88, 90]}


isim = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: ")

# look up the grades and calculate the average
if isim in öğrencinot:
    grades = öğrencinot[isim]
    avg_grade = sum(grades) / len(grades)
    print(f"\n{isim} isimli öğrencinin")
    print(f"1. Sınav Notu: {grades[0]}")
    print(f"2. Sınav Notu: {grades[1]}")
    print(f"3. Sınav Notu: {grades[2]}")
    print(f"Not Ortalaması: {avg_grade:.1f}")
else:
    print(f"Maalesef, {name} adında bir öğrenci kaydedilmemiş.")
# Out:
# Nurefşan isimli öğrencinin
# 1. Sınav Notu: 65
# 2. Sınav Notu: 96
# 3. Sınav Notu: 70
# Not Ortalaması: 77.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
liste=["Bmw","Mercedes","Opel","Mazda"]
# 2-  Liste Kaç elemanlıdır ?
elemansayısı=len(liste)
# 3-  Listenin ilk ve son elemanı nedir ?
print(liste[0])
print(liste[-1])
# 4-  Mazda değerini Toyota ile değiştirin.
liste[-1]="toyota"
print(liste)
# 5-  Listenin -2 indeksindeki değer nedir ?
print(liste[-2])
# 6-  Listenin ilk 3 elemanını alın.
print(liste[0:3])
# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
liste[-2:] = ["Toyota", "Renault"]
print(liste)  # ["Bmw", "Mercedes", "Toyota", "Renault"]
# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
liste.insert(1, "Audi")
liste.insert(2,"Nissan")
print(liste)
# 9- Listenin son elemanını silin.
liste.pop(-1)
print(liste)
# 10- Liste elemanlarını tersten yazdırınız.
liste.reverse()
print(liste)
# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
students = [["Yiğit Bilgi", 2010, (70, 60, 70)],["Sena Turan", 1999, (80, 80, 70)],["Ahmet Turan", 1998, (80, 70, 90)]]

for student in students:
    print(f"Adı Soyadı: {student[0]}\nDoğum Yılı: {student[1]}\nNotları: {student[2]}")
    print("------------------")


# 12- Liste elemanlarını ekrana yazdırınız.

names = ['Ali', 'Yağmur', 'Hakan', 'Deniz']
years = [1998, 2000, 1998, 1987]

for i in range(len(names)):
    print(names[i], years[i])

  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print(names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print(names)

# 15-  "Deniz" ismini listeden siliniz.
names.pop(4)
print(names)

# 16-  "Ali" listenin bir elemanı mıdır ?
if 'Ali' in names:
    print("Listede Ali elemanı mevcut.")
else:
    print("Listede Ali elemanı yok.")
# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print(names)
# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print(names)

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
names.sort()
print(years)
# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.

str = "Chevrolet,Dacia"
liste = str.split(",")
print(liste)
# 21- years dizisinde kaç tane 1998 değeri vardır ?
say= years.count(1998)
print(say)

# 22- years dizisinin tüm elemanlarını siliniz.
del years[0:]  

print(years)

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
brands = []
for i in range(3):
    brand = input("Marka bilgisi girin: ")
    brands.append(brand)

# Listede kaydedilen markaları ekrana yazdırın
print("Kaydedilen markalar: ", brands)
# Out:
# Bmw
# Mazda
# ['Bmw', 'Mercedes', 'Opel', 'toyota']
# Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Audi', 'Nissan', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Audi', 'Nissan', 'Mercedes', 'Toyota']
# ['Toyota', 'Mercedes', 'Nissan', 'Audi', 'Bmw']
# Adı Soyadı: Yiğit Bilgi
# Doğum Yılı: 2010
# Notları: (70, 60, 70)
# ------------------
# Adı Soyadı: Sena Turan
# Doğum Yılı: 1999
# Notları: (80, 80, 70)
# ------------------
# Adı Soyadı: Ahmet Turan
# Doğum Yılı: 1998
# Notları: (80, 70, 90)
# ------------------
# Ali 1998
# Yağmur 2000
# Hakan 1998
# Deniz 1987
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Listede Ali elemanı mevcut.
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# [1998, 2000, 1998, 1987]
# ['Chevrolet', 'Dacia']
# 2
# []
# Kaydedilen markalar:  ['LCW', 'MAVİ', 'DEFACTO']
