# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
class User:
    def __init__(self, name, age, height, weight, bmi_category):
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.bmi_category = bmi_category

def calculate_bmi(height, weight):
    bmi = weight / (height/100) ** 2
    if bmi < 18.5:
        return "Zayıf"
    elif 18.5 <= bmi <= 24.9:
        return "Normal kilolu"
    elif 25 <= bmi <= 29.9:
        return "Fazla kilolu"
    elif 30 <= bmi <= 39.9:
        return "Obez"
    else:
        return "İleri derecede obez"

num_users = int(input("Kaç kullanıcı gireceksiniz? "))

users = []

for i in range(num_users):
    name = input("Adınız ve soyadınız: ")
    age = int(input("Yaşınız: "))
    height = float(input("Boyunuz (cm): "))
    weight = float(input("Kilonuz (kg): "))
    bmi_category = calculate_bmi(height, weight)
    user = User(name, age, height, weight, bmi_category)
    users.append(user)

with open("users.txt", "w") as file:
    for user in users:
        file.write(f"{user.name},{user.age},{user.height},{user.weight},{user.bmi_category}\n")

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

class Smoothie:
    def __init__(self, name, price, ingredients):
        self.name = name
        self.price = price
        self.ingredients = ingredients
    
    def __str__(self):
        return "{} smoothie: {} TL".format(self.name, self.price)
    
class SmoothieMachine:
    def __init__(self):
        self.smoothies = []
        self.sales = []
    
    def add_smoothie(self, smoothie):
        self.smoothies.append(smoothie)
    
    def get_menu(self):
        print("Menü:")
        for smoothie in self.smoothies:
            print(smoothie)
    
    def buy_smoothie(self, smoothie_index):
        smoothie = self.smoothies[smoothie_index]
        date = datetime.datetime.now()
        sale = "{} smoothie, {} TL, {}".format(smoothie.name, smoothie.price, date)
        self.sales.append(sale)
        with open("sales.txt", "a") as f:
            f.write(sale + "\n")
        print("Satın alma işlemi başarılı.")
    
    def get_sales(self):
        print("Satışlar:")
        for sale in self.sales:
            print(sale)
    
def main():
    machine = SmoothieMachine()
    # menüye smoothie ekleme
    machine.add_smoothie(Smoothie("Muz", 8, ["muz", "süt", "bal"]))
    machine.add_smoothie(Smoothie("Çilek", 10, ["çilek", "süt", "yoğurt"]))
    machine.add_smoothie(Smoothie("Ananas", 12, ["ananas", "portakal suyu", "yoğurt"]))
    # kullanıcıya seçenekler sunma
    while True:
        print("1. Menüyü görüntüle")
        print("2. Smoothie satın al")
        print("3. Satışları görüntüle")
        choice = input("Seçiminiz (1-3): ")
        if choice == "1":
            machine.get_menu()
        elif choice == "2":
            machine.get_menu()
            smoothie_index = int(input("Hangi smoothie'yi satın almak istersiniz? (0-{}) ".format(len(machine.smoothies)-1)))
            machine.buy_smoothie(smoothie_index)
        elif choice == "3":
            machine.get_sales()
        else:
            print("Geçersiz seçim.")
    
if __name__ == "__main__":
    main()
# Out:
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# Ananas smoothie: 12 TL
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# Ananas smoothie: 12 TL
# Satın alma işlemi başarılı.
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# Ananas smoothie: 12 TL
# Satın alma işlemi başarılı.
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# Ananas smoothie: 12 TL
# Satın alma işlemi başarılı.
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# Ananas smoothie: 12 TL
# Satın alma işlemi başarılı.
# 1. Menüyü görüntüle
# 2. Smoothie satın al
# 3. Satışları görüntüle
# Menü:
# Muz smoothie: 8 TL
# Çilek smoothie: 10 TL
# ...
